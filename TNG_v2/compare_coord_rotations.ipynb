# %%
import numpy as np
import scipy.linalg as la
import matplotlib.pyplot as plt
plt.style.use('plotting')

# %%
id = 479264

#had to move these files to local machine to plot since I can't access Google Drive through Python
#no rotation
gas = np.loadtxt('/Users/ektapatel/Desktop/raw_particle_data/%s_gas_properties_TNGv2.txt'%id)
stars = np.loadtxt('/Users/ektapatel/Desktop/raw_particle_data/%s_star_properties_TNGv2.txt'%id)
print(len(gas), len(stars))
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.plot(gas[:,0],gas[:,1],',',color='b',alpha=0.2)
plt.plot(stars[:,0],stars[:,1],',',color='m',alpha=0.2)
plt.xlabel('X')
plt.ylabel('Y')

plt.subplot(122)
plt.plot(gas[:,1],gas[:,2],',',color='b',alpha=0.2)
plt.plot(stars[:,1],stars[:,2],',',color='m',alpha=0.2)
plt.xlabel('Y')
plt.ylabel('Z')
plt.tight_layout()
plt.savefig('%s_no_rotation.png'%id)
# Out:
# 95391 54440

# %%
#original rotation
gas = np.loadtxt('/Users/ektapatel/Desktop/coord_rotation_tests/original_rotation/%s_gas_properties_TNGv2_rotated.txt'%id)
stars = np.loadtxt('/Users/ektapatel/Desktop/coord_rotation_tests/original_rotation/%s_star_properties_TNGv2_rotated.txt'%id)
print(len(gas), len(stars))
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.plot(gas[:,0],gas[:,1],',',color='b',alpha=0.2)
plt.plot(stars[:,0],stars[:,1],',',color='m',alpha=0.2)
plt.xlabel('X')
plt.ylabel('Y')

plt.subplot(122)
plt.plot(gas[:,1],gas[:,2],',',color='b',alpha=0.2)
plt.plot(stars[:,1],stars[:,2],',',color='m',alpha=0.2)
plt.xlabel('Y')
plt.ylabel('Z')
plt.tight_layout()
plt.savefig('%s_original_rotation.png'%id)
# Out:
# 95391 54440

# %%
#modified rotation
gas = np.loadtxt('/Users/ektapatel/Desktop/coord_rotation_tests/modified_rotation/%s_gas_properties_TNGv2_rotated.txt'%id)
stars = np.loadtxt('/Users/ektapatel/Desktop/coord_rotation_tests/modified_rotation/%s_star_properties_TNGv2_rotated.txt'%id)
print(len(gas), len(stars))

plt.figure(figsize=(10,5))
plt.subplot(121)
plt.plot(gas[:,0],gas[:,1],',',color='b',alpha=0.2)
plt.plot(stars[:,0],stars[:,1],',',color='m',alpha=0.2)
plt.xlabel('X')
plt.ylabel('Y')

plt.subplot(122)
plt.plot(gas[:,1],gas[:,2],',',color='b',alpha=0.2)
plt.plot(stars[:,1],stars[:,2],',',color='m',alpha=0.2)
plt.xlabel('Y')
plt.ylabel('Z')
plt.tight_layout()
plt.savefig('%s_modified_rotation.png'%id)
# Out:
# 95391 54440
